# %% [markdown]
# # Notebook for testing and development

# %%
import sys
import os
# Add parent directory to path if needed
sys.path.insert(0, os.path.abspath('..'))
import gamified_exam as ge
import pandas as pd
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
#   Cell In[58], line 6
#     import .grader as Difficulty
#            ^
# SyntaxError: invalid syntax

# %%
exam = ge.GamifiedExam("../data/exam_questions.txt")

# %%
# test complete exam
# exam.run_exam()

# %%
question_pool = exam.questions.copy()
question_num = 1
print(type(question_pool))
for q in question_pool: print(q)
# Out:
# <class 'list'>
# Question(prompt='What is the primary fuel for nuclear fusion in main sequence stars?', answer='Hydrogen', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What type of star is the Sun classified as?', answer='Main sequence star', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What color are the coolest stars? (A) Blue (B) White (C) Yellow (D) Red', answer='D', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.MULTICHOICE: 2>)
# Question(prompt='What force causes a protostar to collapse and form?', answer='Gravity', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is a cloud of gas and dust in space where stars form called?', answer='Nebula', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What pressure supports a white dwarf against gravitational collapse?', answer='Electron degeneracy pressure', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the explosive death of a massive star called?', answer='Supernova', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the approximate Chandrasekhar mass limit in solar masses?', answer='1.4', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.NUMERIC: 1>)
# Question(prompt='What stage comes immediately after the main sequence for Sun-like stars?', answer='Red giant', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the remnant left after a Sun-like star dies?', answer='White dwarf', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What fusion process occurs in the core of main sequence stars?', answer='Hydrogen fusion', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='Which element is produced by hydrogen fusion? (A) Helium (B) Carbon (C) Oxygen (D) Iron', answer='A', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.MULTICHOICE: 2>)
# Question(prompt='What is the mass limit called that determines whether a white dwarf is stable?', answer='Chandrasekhar limit', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What process begins when a main sequence star exhaustes hydrogen in its core?', answer='Hydrogen shell burning', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What type of supernova results from a white dwarf exceeding the Chandrasekhar limit?', answer='Type Ia supernova', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What happens to luminosity as a star becomes a red giant? (A) Decreases (B) Stays same (C) Increases (D) Oscillates', answer='C', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.MULTICHOICE: 2>)
# Question(prompt='What element begins fusing in the core during the red giant phase?', answer='Helium', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What does a planetary nebula represent in stellar evolution?', answer='Ejected outer layers of a dying star', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What keeps a planetary nebula visually bright?', answer='Ultraviolet radiation from the central white dwarf', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the minimum stellar mass required for helium fusion?', answer='0.5 Msun', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='What process causes Type II supernovae in massive stars?', answer='Core collapse', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What fusion product accumulates at the center of massive stars before collapse?', answer='Iron', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What phenomenon occurs when a white dwarf accretes matter and undergoes surface fusion?', answer='Nova', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What determines if a supernova remnant becomes a neutron star or black hole? (A) Temperature (B) Composition (C) Core mass (D) Rotation', answer='C', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.MULTICHOICE: 2>)
# Question(prompt='What is the approximate surface temperature of the Sun?', answer='5778 K', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='Name the three main stellar remnants.', answer='White dwarf, Neutron star, Black hole', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.LIST: 4>)
# Question(prompt='What physical principle prevents further compression in electron degenerate matter?', answer='Pauli exclusion principle', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What evolutionary track does a fully convective pre-main sequence star follow?', answer='Hayashi track', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the approximate mass range for electron capture supernovae?', answer='8-12 solar masses', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What nuclear process begins immediately before oxygen fusion in massive stars?', answer='Neon burning', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the nickel-iron decay chain in Type II supernovae?', answer='Nickel-56, Cobalt-56, Iron-56', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.LIST: 4>)
# Question(prompt='What causes pair-instability supernovae in the most massive stars?', answer='Photon pair production reducing pressure support', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What physical process converts protons to neutrons during core collapse?', answer='Electron capture', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='Why does the virial theorem require core heating during gravitational contraction?', answer='Half of gravitational energy heats the core', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the approximate core temperature required to fuse hydrogen?', answer='1e7 K', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='What causes the steep mass-luminosity relation on the main sequence?', answer='Higher core temperature and pressure in massive stars', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the approximate mass-luminosity relation exponent for main sequence stars?', answer='3.5', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.NUMERIC: 1>)
# Question(prompt='What mass separates stars that become white dwarfs from those that explode?', answer='8 Msun', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='What process makes Type Ia supernovae useful as standard candles?', answer='Nearly uniform peak luminosity', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='Why can iron not provide energy through nuclear fusion?', answer='Iron has the highest binding energy per nucleon', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What prevents low-mass red dwarfs from becoming red giants?', answer='They remain fully convective', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 0>)
# Question(prompt='What is the typical neutron star radius?', answer='10 km', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='What is the approximate luminosity of the Sun?', answer='3.8e26 W', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='Name three nuclear burning stages in massive stars.', answer='Hydrogen burning, Helium burning, Carbon burning', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.LIST: 4>)
# Question(prompt='What is the approximate escape velocity from the surface of a neutron star?', answer='0.5 c', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)
# Question(prompt='What is the typical main sequence lifetime of the Sun?', answer='10 Gyr', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.QUANTITY: 3>)

# %%
# Filter questions by current difficulty
print(exam.current_difficulty)
for q in question_pool: print(q.difficulty) ; print(exam.current_difficulty);x = q.difficulty == exam.current_difficulty ; print(x)
available = [q for q in question_pool if q.difficulty == exam.current_difficulty]
print(type(available))
# Out:
# Difficulty.BEGINNER
# Difficulty.BEGINNER
# Difficulty.BEGINNER
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 # Filter questions by current difficulty
#       2 print(exam.current_difficulty)
# ----> 3 for q in question_pool: print(q.difficulty) ; print(exam.current_difficulty);x = q.difficulty == exam.current_difficulty ; print(x)
#       4 available = [q for q in question_pool if q.difficulty == exam.current_difficulty]
#       5 print(type(available))
#
# File <string>:5, in __eq__(self, other)
#
# TypeError: expected 1 argument, got 0

# %%
q = question_pool[0]
print(q.difficulty)
print(exam.current_difficulty)
q.difficulty == exam.current_difficulty
# Out:
# Difficulty.BEGINNER
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 print(exam.current_difficulty)
# ----> 2 q.difficulty == exam.current_difficulty
#
# File <string>:5, in __eq__(self, other)
#
# TypeError: expected 1 argument, got 0

# %%
print(type(q.difficulty))
print(type(exam.current_difficulty))
print(repr(exam.current_difficulty))
# Out:
# <enum 'Difficulty'>
# <enum 'Difficulty'>
# <Difficulty.BEGINNER: 1>

# %%
print("q.difficulty value:", q.difficulty.value)
print("exam.current_difficulty value:", exam.current_difficulty.value)
print("isinstance check:", isinstance(exam.current_difficulty, Difficulty))
result = q.difficulty == exam.current_difficulty
print(result)
# Out:
# q.difficulty value: 1
# exam.current_difficulty value: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 print("q.difficulty value:", q.difficulty.value)
#       2 print("exam.current_difficulty value:", exam.current_difficulty.value)
# ----> 3 print("isinstance check:", isinstance(exam.current_difficulty, Difficulty))
#       4 result = q.difficulty == exam.current_difficulty
#       5 print(result)
#
# NameError: name 'Difficulty' is not defined

# %%
for q in available: print(q)

# %%
q1 = available[0]

print(f"\n[Question {question_num}] [{q1.difficulty.name}] ({q1.points} points)")
print(f"{q1.prompt}")
# Out:
# [Question 1] [BEGINNER] (10 points)
# What is the primary fuel for nuclear fusion in main sequence stars?

# %%
a1 = input("Your answer: ").strip()
print(a1)
# Out:
# w

# %%
ge.Grader.auto_correct(a1, q1.answer)
# Out:
# (False, 0.0, 'Incorrect. ✗ Correct answer: Hydrogen')
