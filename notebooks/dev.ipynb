# %% [markdown]
# # Notebook for testing and development

# %%
import sys
import os
# Add parent directory to path if needed
sys.path.insert(0, os.path.abspath('..'))

from exam import GamifiedExam, Difficulty, Question, AutoGrader
import pandas as pd
import matplotlib.pyplot as plt
