# %% [markdown]
# # Notebook for testing and development

# %%
import sys
import os
# Add parent directory to path if needed
sys.path.insert(0, os.path.abspath('..'))
# import gamified_exam
from gamified_exam import GamifiedExam as ge

# %%
ge.load_questions(ge, filename="../data/exam_questions.txt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ge.load_questions(ge, filename="../data/exam_questions.txt")
#
# File ~/Documents/Teaching/Arizona/gamified_exam/gamified_exam/exam.py:46, in GamifiedExam.load_questions(self, filename)
#      43             difficulty = Difficulty[diff_str.strip().upper()]
#      44             points = int(points_str.strip())
# ---> 46             self.questions.append(Question(
#      47                 prompt=prompt.strip(),
#      48                 answer=answer.strip(),
#      49                 difficulty=difficulty,
#      50                 points=points
#      51             ))
#      52 except FileNotFoundError:
#      53     print(f"Error: File '{filename}' not found.")
#
# AttributeError: type object 'GamifiedExam' has no attribute 'questions'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from gamified_exam import GamifiedExam, Difficulty, Question, AutoGrader
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'GamifiedExam' from 'gamified_exam' (unknown location)
