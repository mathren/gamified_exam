# %% [markdown]
# # Notebook for testing and development

# %%
import sys
import os
# Add parent directory to path if needed
sys.path.insert(0, os.path.abspath('..'))

from gamified_exam import GamifiedExam, Difficulty, Question, AutoGrader
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       3 # Add parent directory to path if needed
#       4 sys.path.insert(0, os.path.abspath('..'))
# ----> 6 from gamified_exam import GamifiedExam, Difficulty, Question, AutoGrader
#       7 import pandas as pd
#       8 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'GamifiedExam' from 'gamified_exam' (unknown location)
