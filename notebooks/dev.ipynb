# %% [markdown]
# # Notebook for testing and development

# %%
import sys
import os
# Add parent directory to path if needed
sys.path.insert(0, os.path.abspath('..'))
# import gamified_exam
from gamified_exam import GamifiedExam 
import pandas as pd
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 sys.path.insert(0, os.path.abspath('..'))
#       5 # import gamified_exam
# ----> 6 from gamified_exam import GamifiedExam
#       7 import pandas as pd
#       8 import matplotlib.pyplot as plt
#
# File ~/Documents/Teaching/Arizona/gamified_exam/gamified_exam/__init__.py:8
#       6 from .exam import GamifiedExam
#       7 from .question import Question, Difficulty
# ----> 8 from .grader import AutoGrader
#      10 __version__ = "0.1.0"
#      11 __all__ = ["GamifiedExam", "Difficulty", "Question", "AutoGrader"]
#
# ImportError: cannot import name 'AutoGrader' from 'gamified_exam.grader' (/home/mrenzo/Documents/Teaching/Arizona/gamified_exam/gamified_exam/grader.py)

# %%
exam = GamifiedExam("../data/exam_questions.txt")

# %%
# test complete exam
# exam.run_exam()

# %%
question_pool = exam.questions.copy()
question_num = 1
print(type(question_pool))
for q in question_pool: print(q)
# Out:
# <class 'list'>
# Question(prompt='What is the primary fuel for nuclear fusion in main sequence stars?', answer='Hydrogen', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What type of star is the Sun classified as?', answer='Main sequence star', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What color are the coolest stars on the main sequence?', answer='Red', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What force causes a protostar to collapse and form?', answer='Gravity', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is a cloud of gas and dust in space where stars form called?', answer='Nebula', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What pressure supports a white dwarf against gravitational collapse?', answer='Electron degeneracy pressure', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the explosive death of a massive star called?', answer='Supernova', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the approximate mass limit for a white dwarf in solar masses?', answer='1.4 solar masses', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What stage comes immediately after the main sequence for Sun-like stars?', answer='Red giant', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the remnant left after a Sun-like star dies?', answer='White dwarf', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What fusion process occurs in the core of main sequence stars?', answer='Hydrogen fusion to helium', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the main heat transfer mechanism in white dwarf interiors?', answer='Conduction', difficulty=<Difficulty.BEGINNER: 1>, points=10, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the mass limit called that determines whether a white dwarf is stable?', answer='Chandrasekhar limit', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What process begins when a main sequence star exhausts hydrogen in its core?', answer='Hydrogen shell burning', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What type of supernova results from a white dwarf exceeding the Chandrasekhar limit?', answer='Type Ia supernova', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt="What happens to a star's luminosity as it moves from main sequence to red giant?", answer='Luminosity increases', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What element begins fusing in the core during the red giant phase?', answer='Helium', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the region to the right of the Hayashi line called in stellar evolution?', answer='Forbidden region', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What does a planetary nebula represent in stellar evolution?', answer='Ejected outer layers of a dying low-mass star', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What keeps a planetary nebula visually bright?', answer='Ultraviolet radiation from the hot white dwarf', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What timescale does a protostar contract on when descending the Hayashi track?', answer='Kelvin-Helmholtz timescale', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the minimum stellar mass required for helium fusion to occur?', answer='0.6 solar masses', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What process causes Type II supernovae in massive stars?', answer='Core collapse', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What fusion product accumulates at the center of massive stars before collapse?', answer='Iron', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What phenomenon occurs when a white dwarf accretes matter and undergoes surface fusion?', answer='Nova', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What determines whether a supernova remnant becomes a neutron star or black hole?', answer='Core mass', difficulty=<Difficulty.INTERMEDIATE: 2>, points=20, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What physical principle prevents further compression in electron degenerate matter?', answer='Pauli exclusion principle', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What evolutionary track does a star follow when fully convective during pre-main sequence?', answer='Hayashi track', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the approximate mass range for stars that undergo electron capture supernovae?', answer='8 to 12 solar masses', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What nuclear process begins immediately before oxygen fusion in massive stars?', answer='Neon burning', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What decay chain provides energy to Type II supernova light curves weeks after explosion?', answer='Nickel-56 to Cobalt-56 to Iron-56', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What causes pair-instability supernovae in the most massive stars?', answer='Photon pair production reducing pressure support', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What physical process converts protons to neutrons during core collapse?', answer='Electron capture', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='Why does the virial theorem require core heating during gravitational contraction?', answer='Half of gravitational energy heats the core, half is radiated away', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What is the main reason stellar evolution is more predictive than star formation theory?', answer='Stars are in hydrostatic equilibrium with well-defined boundary conditions', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What causes the steep mass-luminosity relation on the zero-age main sequence?', answer='Higher core temperature and pressure in more massive stars', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What happens to stellar radius during contraction along the Hayashi line?', answer='Radius decreases while luminosity decreases', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What mass limit separates stars that become white dwarfs from those that explode?', answer='Approximately 8 solar masses initial mass', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What process makes Type Ia supernovae useful as standard candles in cosmology?', answer='They have nearly uniform peak luminosity', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='Why can iron not provide energy through nuclear fusion in stellar cores?', answer='Iron has the highest binding energy per nucleon', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)
# Question(prompt='What prevents low-mass red dwarfs from becoming red giants?', answer='They remain fully convective and burn hydrogen throughout their entire mass', difficulty=<Difficulty.ADVANCED: 3>, points=30, question_type=<QuestionType.TEXT: 2>)

# %%
# Filter questions by current difficulty
available = [q for q in question_pool if q.difficulty == exam.current_difficulty]
print(type(available))
# Out:
# <class 'list'>

# %%
q1 = available[0]

print(f"\n[Question {question_num}] [{q1.difficulty.name}] ({q1.points} points)")
print(f"{q1.prompt}")
# Out:
# [Question 1] [BEGINNER] (10 points)
# What is the primary fuel for nuclear fusion in main sequence stars?

# %%
a1 = input("Your answer: ").strip()
print(a1)
# Out:
# culo    999
